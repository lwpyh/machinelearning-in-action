# %%
import numpy as np
#from imp import reload 
#reload (logRegres)
import logRegres
dataArr,labelMat=logRegres.loadDataSet()
logRegres.gradDesent(dataArr,labelMat)
# Out:
# array([[14.41184059],
#        [ 1.23046795],
#        [-1.95725202]])

# %%
from imp import reload 
reload (logRegres)
dataArr,labelMat=logRegres.loadDataSet()
weights=logRegres.gradDesent(dataArr,labelMat)
logRegres.plotBestFit(weights)

# %%
from numpy import *
reload (logRegres)
dataArr,labelMat=logRegres.loadDataSet()
weights=logRegres.stocGranfAscent0(array(dataArr),labelMat)
logRegres.plotBestFit(weights)

# %%
reload (logRegres)
dataArr,labelMat=logRegres.loadDataSet()
weights=logRegres.stocGranfAscent1(array(dataArr),labelMat)
logRegres.plotBestFit(weights)

# %%
reload(logRegres)
logRegres.multiTest()
# Out:
# /home/jian/logRegres.py:19: RuntimeWarning: overflow encountered in exp
#   return (1.0/(1.0+np.exp(-inX)))
# 测试集错误率为: 25.37%
# 测试集错误率为: 31.34%
# 测试集错误率为: 40.30%
# 测试集错误率为: 41.79%
# 测试集错误率为: 46.27%
# 测试集错误率为: 40.30%
# 测试集错误率为: 40.30%
# 测试集错误率为: 53.73%
# 测试集错误率为: 38.81%
# 测试集错误率为: 43.28%
# after 10 iteration the zverage error rate is:                  40.149254
